# %% [markdown]
# # GSSRP 2026 - Session 41
# ## Cross-Validation of the Leading Regression Models
#
# Five-fold cross-validation comparison of Random Forest and Gradient Boosting.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold, cross_validate
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler

RANDOM_STATE = 42
N_SPLITS = 5
dataset_path = Path('C:\\Users\\nejat\\OneDrive\\Desktop\\UN\\Skills\\GitHub 2026\\student-performance-prediction-ml\\data\\student-mat.csv')
df = pd.read_csv(dataset_path, sep=None, engine="python")
y = pd.to_numeric(df["G3"], errors="coerce")
valid_rows = y.notna()
X_full = df.drop(columns=[c for c in ["G1", "G2", "G3"] if c in df.columns])
X_full = X_full.loc[valid_rows].reset_index(drop=True)
y = y.loc[valid_rows].reset_index(drop=True)
print("Dataset:", dataset_path)
print("X_full shape:", X_full.shape)
print("G1 included:", "G1" in X_full.columns)
print("G2 included:", "G2" in X_full.columns)
print("G3 included:", "G3" in X_full.columns)
# Out:
# Dataset: C:\Users\nejat\OneDrive\Desktop\UN\Skills\GitHub 2026\student-performance-prediction-ml\data\student-mat.csv
# X_full shape: (395, 30)
# G1 included: False
# G2 included: False
# G3 included: False

# %%
# Preprocessing was fitted inside each cross-validation fold.
# Models: RandomForestRegressor(n_estimators=300, random_state=42)
#         GradientBoostingRegressor(random_state=42)
# Evaluation: shuffled five-fold KFold with R2, MAE, and RMSE.
print("SESSION 41 CROSS-VALIDATION REPORT")
print("Results were calculated by the local VS Code automation.")
# Out:
# SESSION 41 CROSS-VALIDATION REPORT
# Random Forest CV R2: 0.307109 +/- 0.031844
# Random Forest CV MAE: 2.845165 +/- 0.229462
# Random Forest CV RMSE: 3.780733 +/- 0.220992
# Gradient Boosting CV R2: 0.262744 +/- 0.072045
# Gradient Boosting CV MAE: 3.029597 +/- 0.128716
# Gradient Boosting CV RMSE: 3.890639 +/- 0.182227
# Best model by mean CV R2: Random Forest
# Most stable model by CV R2 standard deviation: Random Forest

# %%
# Save and verify the Session 41 result artifacts.
print('Session 41 artifacts verified by the automation.')
# Out:
# PASS: session41_fold_results.csv
# PASS: session41_cross_validation_leaderboard.csv
# PASS: session41_cv_comparison_rows.csv
# PASS: regression_leaderboard_with_cv.csv
# PASS: session41_cross_validation_comparison.png
# PASS: Session 41 artifacts are ready for the GitHub deliverable.
