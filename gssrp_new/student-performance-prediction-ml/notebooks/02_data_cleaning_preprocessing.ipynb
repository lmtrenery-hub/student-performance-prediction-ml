# %% [markdown]
# # Session 10: Missing Values and Duplicates
#
# ## Purpose
#
# This notebook checks the Student Performance dataset for missing values and duplicate rows before preprocessing, feature engineering, and model development.

# %% [markdown]
# ## Step 1: Import Required Libraries and Load the Dataset

# %% [markdown]
# ## Step 2: Check Missing Values Per Column

# %%
print("Missing per column:")
print(df.isna().sum())
# Out:
# Missing per column:
# school 0
# sex 0
# age 0
# address 0
# famsize 0
# Pstatus 0
# Medu 0
# Fedu 0
# Mjob 0
# Fjob 0
# reason 0
# guardian 0
# traveltime 0
# studytime 0
# failures 0
# schoolsup 0
# famsup 0
# paid 0
# activities 0
# nursery 0
# higher 0
# internet 0
# romantic 0
# famrel 0
# freetime 0
# goout 0
# Dalc 0
# Walc 0
# health 0
# absences 0
# G1 0
# G2 0
# G3 0

# %% [markdown]
# ## Step 3: Check Total Missing Values

# %%
total_missing = int(df.isna().sum().sum())
print("Total missing values:", total_missing)
# Out:
# Total missing values: 0

# %% [markdown]
# ## Step 4: Check Duplicate Rows

# %%
duplicate_rows = int(df.duplicated().sum())
print("Duplicate rows:", duplicate_rows)
# Out:
# Duplicate rows: 0

# %% [markdown]
# ## Step 5: Missing-Value Summary Table

# %%
missing_summary = pd.DataFrame({
    "Column": df.columns,
    "Missing_Count": df.isna().sum().values,
    "Missing_Percent": (df.isna().mean().values * 100).round(2)
})

missing_summary
# Out:
# Missing-value summary table created for 33 columns.

# %% [markdown]
# ## Step 6: Prompt-Engineered Explanation Result
#
# ### Summary
#
# The dataset contains **0 missing values** and **0 duplicate rows**.
#
# ### Interpretation
#
# Every column has zero missing values. Applying imputation would be unnecessary and could introduce artificial information. The duplicate-row count is zero, so repeated records will not receive unintended additional influence.
#
# ### Recommendation
#
# No imputation is needed. No duplicate rows need to be removed.

# %% [markdown]
# ## Step 7: Cleaning Decision
#
# | Data-Quality Issue | Result | Decision |
# |---|---:|---|
# | Missing values | 0 | No imputation is needed. |
# | Duplicate rows | 0 | No duplicate rows need to be removed. |
#
# ## Final Recommendation
#
# No cleaning action is required for missing values or duplicate rows. The dataset is ready for preprocessing and feature engineering.

# %% [markdown]
# ## Step 8: Reflection Question
#
# **Why is documenting "no cleaning needed" just as important as documenting cleaning steps?**
#
# Documenting the result proves that the data-quality check was performed rather than skipped. It makes the workflow transparent and reproducible by showing the evidence supporting each cleaning decision.
